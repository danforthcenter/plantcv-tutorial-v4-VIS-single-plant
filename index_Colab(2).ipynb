# %% [markdown]
# # Welcome to the Photobooth Side View, Single Plant Tutorial, with an example! You can find this exact photobooth in the C basement. If you have multiple plants or separated leaves in the same image, use a different tutorial. This is for Release-4.0!
#
# Made by: Katie Murphy
# Updated: May 5, 2025

# %% [markdown]
# First, import the necessary package. If you get an error here, make sure your kernel (upper right) is set to PlantCV, and that you have PlantCV installed.

# %%
# Install PlantCV and required dependencies
# %pip install "altair>=5" ipympl plantcv

# Give access and mount your Google Drive (need a Google Account)
# Change path to directory you wish output files to be saved to.
from google.colab import drive
drive.mount('/content/gdrive')

# Enable widget feature with matplotlib
from google.colab import output
output.enable_custom_widget_manager()

#View working directory, may need to change path
# %pwd
# Out:
# Requirement already satisfied: altair>=5 in /usr/local/lib/python3.11/dist-packages (5.5.0)
# Collecting ipympl
#   Downloading ipympl-0.9.7-py3-none-any.whl.metadata (8.7 kB)
# Collecting plantcv
#   Downloading plantcv-4.8-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair>=5) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair>=5) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair>=5) (1.47.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from altair>=5) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from altair>=5) (4.14.1)
# Requirement already satisfied: ipython<10 in /usr/local/lib/python3.11/dist-packages (from ipympl) (7.34.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.11/dist-packages (from ipympl) (7.7.1)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from ipympl) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ipympl) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from ipympl) (11.2.1)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.11/dist-packages (from ipympl) (5.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from plantcv) (2.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from plantcv) (2.9.0.post0)
# Requirement already satisfied: scipy<1.16 in /usr/local/lib/python3.11/dist-packages (from plantcv) (1.15.3)
# Requirement already satisfied: scikit-image>=0.19 in /usr/local/lib/python3.11/dist-packages (from plantcv) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from plantcv) (1.6.1)
# Requirement already satisfied: dask in /usr/local/lib/python3.11/dist-packages (from plantcv) (2024.12.1)
# Collecting dask-jobqueue (from plantcv)
#   Downloading dask_jobqueue-0.9.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from plantcv) (4.11.0.86)
# Requirement already satisfied: xarray>=2022.11.0 in /usr/local/lib/python3.11/dist-packages (from plantcv) (2025.3.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from plantcv) (0.14.5)
# Collecting vl-convert-python (from plantcv)
#   Downloading vl_convert_python-1.8.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting nd2 (from plantcv)
#   Downloading nd2-0.10.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl) (75.2.0)
# Collecting jedi>=0.16 (from ipython<10->ipympl)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.15)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair>=5) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair>=5) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair>=5) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair>=5) (0.26.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->plantcv) (1.17.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.19->plantcv) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.19->plantcv) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.19->plantcv) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.19->plantcv) (0.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->plantcv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->plantcv) (2025.2)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask->plantcv) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask->plantcv) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask->plantcv) (2025.3.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask->plantcv) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask->plantcv) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask->plantcv) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask->plantcv) (8.7.0)
# Requirement already satisfied: distributed>=2022.02.0 in /usr/local/lib/python3.11/dist-packages (from dask-jobqueue->plantcv) (2024.12.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair>=5) (3.0.2)
# Collecting ome-types>=0.5.1 (from nd2->plantcv)
#   Downloading ome_types-0.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting resource-backed-dask-array (from nd2->plantcv)
#   Downloading resource_backed_dask_array-0.1.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->plantcv) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->plantcv) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->plantcv) (1.0.1)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (1.1.1)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.11/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (3.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (6.4.2)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.11/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (2.4.0)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (3.0.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask->plantcv) (3.23.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.1.12)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (24.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.4)
# Collecting pydantic-extra-types (from ome-types>=0.5.1->nd2->plantcv)
#   Downloading pydantic_extra_types-2.10.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pydantic>=2.4 in /usr/local/lib/python3.11/dist-packages (from ome-types>=0.5.1->nd2->plantcv) (2.11.7)
# Collecting xsdata<24.4,>=23.6 (from ome-types>=0.5.1->nd2->plantcv)
#   Downloading xsdata-24.3.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython<10->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<10->ipympl) (0.2.13)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.5.7)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.8.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4->ome-types>=0.5.1->nd2->plantcv) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4->ome-types>=0.5.1->nd2->plantcv) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4->ome-types>=0.5.1->nd2->plantcv) (0.4.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (4.3.8)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.21.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.22)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.3.1)
# Downloading ipympl-0.9.7-py3-none-any.whl (515 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.7/515.7 kB 15.3 MB/s eta 0:00:00
# Downloading plantcv-4.8-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 kB 20.3 MB/s eta 0:00:00
# Downloading dask_jobqueue-0.9.0-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.1 MB/s eta 0:00:00
# Downloading nd2-0.10.3-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 6.3 MB/s eta 0:00:00
# Downloading vl_convert_python-1.8.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 57.6 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.2 MB/s eta 0:00:00
# Downloading ome_types-0.6.1-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.1/245.1 kB 18.4 MB/s eta 0:00:00
# Downloading resource_backed_dask_array-0.1.0-py2.py3-none-any.whl (8.0 kB)
# Downloading xsdata-24.3.1-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.1/224.1 kB 17.1 MB/s eta 0:00:00
# Downloading pydantic_extra_types-2.10.5-py3-none-any.whl (38 kB)
# Installing collected packages: xsdata, vl-convert-python, jedi, pydantic-extra-types, resource-backed-dask-array, ome-types, dask-jobqueue, nd2, plantcv, ipympl
# Successfully installed dask-jobqueue-0.9.0 ipympl-0.9.7 jedi-0.19.2 nd2-0.10.3 ome-types-0.6.1 plantcv-4.8 pydantic-extra-types-2.10.5 resource-backed-dask-array-0.1.0 vl-convert-python-1.8.0 xsdata-24.3.1
# Mounted at /content/gdrive
# '/content'

# %%
# %matplotlib inline
from plantcv import plantcv as pcv
from plantcv.parallel import WorkflowInputs

# %%
# Change your working directory to the mounted drive
# %cd gdrive/MyDrive/
# Print the contents of your drive to confirm it worked
# !ls
# Clone the workshop's repository to your Google Drive
# !git clone https://github.com/danforthcenter/plantcv-tutorial-v4-VIS-single-plant.git
# Out:
# /content/gdrive/MyDrive
#  90finalplotsEX10.csv
#  90finalplotsEX10.gsheet
#  90finalplotsEX6.csv
#  90finalplotsEX6.gsheet
#  90finalplotsEX7.csv
#  90finalplotsEX7.gsheet
#  90finalplotsEX8.csv
#  90finalplotsEX8.gsheet
#  90finalplotsEX9.csv
#  90finalplotsEX9.gsheet
#  bg1b108_plate2_2025_02_21.jpeg
#  bg1b108_plate2_2025_02_21.jpg
#  bg1b73_plate2_2025_02_21.jpg
#  bg1B84_plate2_2025-02-04.jpg
#  bg1B97_plate2_2025-02-04.jpg
#  bg1cml103_plate2_2025_02_21.jpg
#  bg1cml228_plate2_2025_02_21.jpg
#  bg1CML247_plate2_2025-02-04.jpg
#  bg1cml277_plate2_2025_02_21.jpg
#  bg1cml322_plate2_2025_02_21.jpg
#  bg1CmL333_plate2_2025-02-04.jpg
#  bg1cml52_plate2_2025_02_21.jpg
#  bg1cr1ht_plate2_2025_02_21.jpg
#  bg1hp301_plate2_2025_02_21.jpg
#  bg1IL14H_plate2_2025-02-04.jpg
#  bg1Ki11_plate2_2025-02-04.jpg
#  bg1ki3_plate2_2025_02_21.jpg
#  bg1ky21_plate2_2025_02_2021.jpg
#  bg1lh145_plate2_2025_02_21.jpg
#  bg1LH149_plate2_2025-02-04.jpg
#  bg1LH197_plate2_2025-02-04.jpg
#  bg1m162w_plate2_2025_02_21.jpg
#  bg1M37W_plate2_2025-02-04.jpg
#  bg1minimaize_plate2_2025_02_21.jpg
#  bg1ms71_plate2_2025_02_21.jpg
#  bg1NC350_plate2_2025-02-04.jpg
#  bg1NC358_plate2_2025-02-04.jpg
#  bg1nkh8431_plate2_2025_02_21.jpg
#  bg1OH33_plate2_2025-02-04.jpg
#  bg1Oh7B_plate2_2025-02-04.jpg
#  bg1OOH43_plate2_2025-02-04.jpg
#  bg1P39_plate2_2025-02-04.jpg
#  bg1ph207_plate2_2025_02_21.jpg
#  bg1PHB47_plate2_2025-02-04.jpg
#  bg1phg29_plate2_2025_02_21.jpg
#  bg1PHG47_plate2_2025-02-04.jpg
#  bg1PHG50_plate2_2025-02-04.jpg
#  bg1phg72_plate2_2025_02_21.jpg
#  bg1PHG80_plate2_2025-02-04.jpg
#  bg1phj40_plate2_2025_02_21.jpg
#  bg1phw65_plate2_2025_02_21.jpg
#  bg1Tx303_plate2_2025-02-04.jpg
#  bg1Tzi8_plate2_2025-02-04.jpg
#  bg1w604s_plate2_2025_02_21.jpg
#  bg2b108_plate2_2025_02_21.jpeg
#  bg2b108_plate2_2025_02_21.jpg
#  bg2b73_plate2_2025_02_21.jpg
#  bg2B84_plate2_2025-02-04.jpg
#  BisonFly_ESeigelP2P.pdf
# 'Colab Notebooks'
# 'Copy of 2025-professional-development-conversation.gdoc'
# 'Copy of Copy of Resume_ElizaSeigel.gdoc'
# 'Copy of xray_seeds_maize.gsheet'
#  CV_ElizaSeigel.gdoc
# 'danforthretreat2019poster (1).pptx'
#  data_output.json
#  DataPCVG.gsheet
#  DataTotal.csv
#  DataTotalFinal.gsheet
#  DataTotal.gsheet
#  drawing.gdraw
# 'Eliza Seigel 2025-professional-development-conversation.gdoc'
#  ElizaSeigel_CoverLetter1.gdoc
#  ElizaSeigel_CoverLetter2.gdoc
#  ElizaSeigel_CoverLetter3.gdoc
#  ElizaSeigel_DDPSCRetreat_LightningTalk.gslides
#  ElizaSeigel_DDPSCRetreat_Poster.gslides
#  ElizaSeigel_Resume.gdoc
#  FINALImageAnalysis.ipynb
#  finalplotsEX10.csv
#  finalplotsEX10.gsheet
# 'finalplotsEX6 (1).csv'
#  finalplotsEX6.csv
#  finalplotsEX6.gsheet
# 'finalplotsEX7 (1).gsheet'
#  finalplotsEX7.csv
#  finalplotsEX7.gsheet
#  finalplotsEX8.csv
#  finalplotsEX8.gsheet
#  finalplotsEX9.csv
#  finalplotsEX9.gsheet
# 'Finley et al Agrobacterium-Mediated Transformation ofSetaria viridis.gdoc'
# 'Geospatial project'
#  img2.png
#  img3.png
# 'Job Sharing Pivot 2 Plants.gsheet'
# 'Journal Club Notes.gdoc'
# 'July 2025-professional-development-conversation.gdoc'
# 'Lab Meeting Presentation Draft.gslides'
# 'Lab Meeting Presentation.gslides'
# 'Lightning Talk Draft.gdoc'
# 'Maize planting.gdoc'
# 'MOBOT Notes.gdoc'
# 'pcvg90 w rank.gsheet'
# 'PlantCV Meeting Notes.gdoc'
#  plantcv-tutorial-vis-nir
#  Resume_ElizaSeigel.gdoc
#  Retreat2024_lightningtalk_6.3.pptx
#  training-image.png
#  Tutorial.gdoc
#  Untitled
#  Untitled0.ipynb
# Cloning into 'plantcv-tutorial-v4-VIS-single-plant'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 108 (delta 47), reused 48 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (108/108), 18.17 MiB | 14.88 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %% [markdown]
# Next, import a sample image. Your images need to be on the server. Remember, always keep your raw images separate from your newly processed images! You will need to change the path to your image, and also if you want specific output folders and directories.

# %%
# Input/output options
args = WorkflowInputs(
    images=["./plantcv-tutorial-v4-VIS-single-plant/imgs/1_B73_sand_C_2023-04-14_10:19:07.jpg"],
    names="image",
    result="example_results_oneimage_file.json",
    outdir=".",
    writeimg=False,
    debug="plot"
    )

# %%
# Set debug to the global parameter
pcv.params.debug = args.debug
# Change display settings
pcv.params.dpi = 100
pcv.params.text_size = 20
pcv.params.text_thickness = 20

# %%
# Read in your image, which is based on the path you put above

# Inputs:
#   filename - Image file to be read in
#   mode - Return mode of image; either 'native' (default), 'rgb', 'gray', or 'csv'
img, path, filename = pcv.readimage(filename=args.image)

# %%
# Crop image if necessary. This is optional.
crop_img = pcv.crop(img=img, x=1500, y=0, h=2900, w=2500)

# %%
# If your image is not straight, rotate it. Here our image is straight becasue our camera was on a flat surface, so we will rotate 0 degrees.

rotate_img = pcv.transform.rotate(crop_img, 0, False)

# %%
#First, find the color card. You won't see any output of this function.

dataframe1 = pcv.transform.detect_color_card(rgb_img=rotate_img, radius=10)
# Out:
# DeprecationWarning: The 'label' parameter is no longer utilized, since color chip size is now metadata. It will be removed in PlantCV v5.0. Current PlantCV version: 4.8

# %%
#Make a color card matrix

headers, card_matrix = pcv.transform.get_color_matrix(rgb_img=rotate_img, mask=dataframe1)

# %%
# Define the standard color card matrix, we know what the colors of those chips should be in a "perfect" image, so we will correct to those values
# Look at where your white chip is in the image to determine which position your card is in (pos)


#pos     = reference value indicating orientation of the color card. The reference
       #         is based on the position of the white chip:
        #        pos = 0: bottom-left corner
        #        pos = 1: bottom-right corner
        #        pos = 2: top-right corner
        #        pos = 3: top-left corner

std_color_matrix = pcv.transform.std_color_matrix (pos=3)

# %%
#Color correct your image to the standard values
#look at the image - does the color look good? If it looks crazy, you probably don't have the card found well and need to go back and define the start and spacing for the card

img_cc = pcv.transform.affine_color_correction(rotate_img, card_matrix, std_color_matrix)
pcv.plot_image(img_cc)

# %%
# IMPORTANT NOTE: Do not run this cell if you are viewing in Binder. This will crash the notebook.

# Update params related to plotting so we can see better
pcv.params.text_size=50
pcv.params.text_thickness=15


#Look at the colorspace - which of these looks the best for masking? Which channel makes the plant look most distinct?
colorspace_img = pcv.visualize.colorspaces(rgb_img=img_cc)

# %%
#If you want to save your color corrected image, do so here. Do NOT save over your raw image.
#We are saving as a temporary image here becasue we want to use it for thresholding.

pcv.print_image(img_cc, filename = "./plantcv-tutorial-v4-VIS-single-plant/color_corrected_img_temp.png")

# %%
#Visualize all the colors to make decisions on how to threshold. I picked the two channels from the colorspace above that looked distinct

color_scatter = pcv.visualize.pixel_scatter_plot(paths_to_imgs = ["./plantcv-tutorial-v4-VIS-single-plant/color_corrected_img_temp.png"] , x_channel = "a", y_channel ="b" )

# %%
#Threshold your image by choosing points in the plot that will separate the green plant pixels from everything else.
# It will draw a line between your two points and take every pixel "above" (if set to true). Do you get all of the plant?

thresh1 = pcv.threshold.dual_channels(rgb_img = img_cc, x_channel = "a", y_channel = "b", points = [(80,80),(125,140)], above=True)

# %%
# Fill in small objects if the above threshold looks like there are "holes" in the leaves
a_fill_image = pcv.fill(bin_img=thresh1, size=50)
a_fill_image = pcv.fill_holes(a_fill_image)

pcv.plot_image(a_fill_image)

# %%
# Define the region of interest (ROI). This should include your plant, but not you color card or other things.

# Inputs:
#   img - RGB or grayscale image to plot the ROI on
#   x - The x-coordinate of the upper left corner of the rectangle
#   y - The y-coordinate of the upper left corner of the rectangle
#   h - The height of the rectangle
#   w - The width of the rectangle

pcv.params.debug = "plot"

roi1 = pcv.roi.rectangle(img=img_cc, x=540, y=0, h=2500, w=1500)

# %%
# Make a new filtered mask that only keeps the plant in your ROI and not objects outside of the ROI
# We have set to partial here so that if a leaf extends outside of your ROI it will still be selected. Switch to "cutto" if you have other plants that are getting selected on accident

# Inputs:
#    mask            = the clean mask you made above
#    roi            = the region of interest you specified above
#    roi_type       = 'partial' (default, for partially inside the ROI), 'cutto', or
#                     'largest' (keep only largest contour)

kept_mask  = pcv.roi.filter(mask=a_fill_image, roi=roi1, roi_type='partial')

# %%
############### Analysis ################

# Find shape properties, data gets stored to an Outputs class automatically

# Inputs:
#   img - RGB or grayscale image data
#   labeled_mask - the mask of each individual object, set by the create_labels function.
#   n_labels - the number of objects, set by the create_labels function.

analysis_image = pcv.analyze.size(img=img_cc, labeled_mask=kept_mask)

# %%
# Shape properties relative to user boundary line (optional). This is useful if your plant is hanging below the pot and you want height from the top of the pot.
# Set your line_position by finding the x-value at the top of the pot, hover your cursor to get that value

# Inputs:
#   img - RGB or grayscale image data
#   obj - Single or grouped contour object
#   mask - Binary mask of selected contours
#   line_position - Position of boundary line (a value of 0 would draw a line
#                   through the bottom of the image)
#   label - Optional label parameter, modifies the variable name of observations recorded. (default `label="default"`)filled_img = pcv.morphology.fill_segments(mask=cropped_mask, objects=edge_objects)

boundary_image = pcv.analyze.bound_horizontal(img=img_cc,labeled_mask=kept_mask,
                                               line_position=2380, label="default")

# %%
# Determine color properties: Histograms, Color Slices and Pseudocolored Images, output color analyzed images (optional)

# Inputs:
#   rgb_img - RGB image data
#   mask - Binary mask of selected contours
#   colorspaces - 'all' (default), 'rgb', 'lab', or 'hsv'
#                 This is the data to be printed to the SVG histogram file
#   label - Optional label parameter, modifies the variable name of observations recorded. (default `label="default"`)

color_histogram = pcv.analyze.color(rgb_img=img_cc, labeled_mask=kept_mask, colorspaces='all', label="default")
# Out:
# alt.FacetChart(...)

# %%
# The save results function will take the measurements stored when running any PlantCV analysis functions, format,
# and print an output text file for data analysis. The Outputs class stores data whenever any of the following functions
# are ran: analyze_bound_horizontal, analyze_bound_vertical, analyze_color, analyze_nir_intensity, analyze_object,
# fluor_fvfm, report_size_marker_area, watershed. If no functions have been run, it will print an empty text file

#This saves results for one image, and each image is saved individually if you run another image (it will overwrite the last one)
pcv.outputs.save_results(filename=args.result)

# %% [markdown]
# ## Congrats, you now know all the settings you like for this day of imaging! It's time to make this into a workflow so that it will analyze all your images at once and you can go have a cup of coffee. To do so, go back to the folder and open up the config_template.json file, and the config_workflow.py files, and you will edit them according to the values you changed in this file.
